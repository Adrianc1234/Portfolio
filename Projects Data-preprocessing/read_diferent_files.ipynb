# %% [markdown]
# # importar txt

# %%
import urllib3
url="http://www.gutenberg.org/files/76/76-0.txt "
http=urllib3.PoolManager()
resp=http.request('GET',url)

# %%
resp

# %%
datos=resp.data.decode('UTF-8')

# %%
print(datos)
# Out:
# ﻿
# The Project Gutenberg EBook of Adventures of Huckleberry Finn, Complete
# by Mark Twain (Samuel Clemens)
#
# This eBook is for the use of anyone anywhere at no cost and with almost
# no restrictions whatsoever. You may copy it, give it away or re-use
# it under the terms of the Project Gutenberg License included with this
# eBook or online at www.gutenberg.net
#
# Title: Adventures of Huckleberry Finn, Complete
#
# Author: Mark Twain (Samuel Clemens)
#
# Release Date: August 20, 2006 [EBook #76]
# Last Updated: February 23, 2018
# Language: English
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK HUCKLEBERRY FINN ***
#
# Produced by David Widger
#
#
#
#
#
# ADVENTURES
#
# OF
#
# HUCKLEBERRY FINN
#
# (Tom Sawyer's Comrade)
#
# By Mark Twain
#
# Complete
#
#
#
#
# CONTENTS.
#
# CHAPTER I. Civilizing Huck.--Miss Watson.--Tom Sawyer Waits.
#
# CHAPTER II. The Boys Escape Jim.--Torn Sawyer's Gang.--Deep-laid Plans.
#
# ...

# %% [markdown]
# # importar csv con pandas

# %%
import csv
import urllib.request
from io import StringIO

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/forest-fires/forestfires.csv'
resp = urllib.request.urlopen(url)
file = StringIO(bytearray(resp.read()).decode())
archivo = csv.reader(file)
for f in archivo:
    print(f)
# Out:
# ['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area']
# ['7', '5', 'mar', 'fri', '86.2', '26.2', '94.3', '5.1', '8.2', '51', '6.7', '0', '0']
# ['7', '4', 'oct', 'tue', '90.6', '35.4', '669.1', '6.7', '18', '33', '0.9', '0', '0']
# ['7', '4', 'oct', 'sat', '90.6', '43.7', '686.9', '6.7', '14.6', '33', '1.3', '0', '0']
# ['8', '6', 'mar', 'fri', '91.7', '33.3', '77.5', '9', '8.3', '97', '4', '0.2', '0']
# ['8', '6', 'mar', 'sun', '89.3', '51.3', '102.2', '9.6', '11.4', '99', '1.8', '0', '0']
# ['8', '6', 'aug', 'sun', '92.3', '85.3', '488', '14.7', '22.2', '29', '5.4', '0', '0']
# ['8', '6', 'aug', 'mon', '92.3', '88.9', '495.6', '8.5', '24.1', '27', '3.1', '0', '0']
# ['8', '6', 'aug', 'mon', '91.5', '145.4', '608.2', '10.7', '8', '86', '2.2', '0', '0']
# ['8', '6', 'sep', 'tue', '91', '129.5', '692.6', '7', '13.1', '63', '5.4', '0', '0']
# ['7', '5', 'sep', 'sat', '92.5', '88', '698.6', '7.1', '22.8', '40', '4', '0', '0']
# ...

# %% [markdown]
# # importar json

# %%
    import requests
    import json
    respuesta = requests.get('http://ip-api.com/json/208.80.152.201')
    file=json.loads(respuesta.content)
    print(file)
# Out:
# {'as': 'AS14907 Wikimedia Foundation Inc.', 'city': 'Dallas', 'country': 'United States', 'countryCode': 'US', 'isp': 'Wikimedia Foundation Inc.', 'lat': 32.7767, 'lon': -96.797, 'org': 'Wikimedia Foundation Inc', 'query': '208.80.152.201', 'region': 'TX', 'regionName': 'Texas', 'status': 'success', 'timezone': 'America/Chicago', 'zip': '75270'}

# %% [markdown]
# # importar xls

# %%
import requests
url = "http://www.muellerindustries.com/uploads/pdf/UW SPD0114.xls"
respuesta = requests.get(url)
with open('test.xls', 'wb') as file:
    file.write(respuesta.content)

# %% [markdown]
# # import  xlsx

# %%
import pandas as pd
url=
